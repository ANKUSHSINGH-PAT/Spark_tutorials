# %%
import pyspark

# %%
from pyspark.sql import SparkSession

# %%
spark=SparkSession.builder.appName('Basics').getOrCreate()

# %%
df=spark.read.json('D:\Desktop\Python_DataScience\Spark\Spark_tutorials\people.json')

# %%
df.printSchema()
# Out:
# root
#  |-- age: long (nullable = true)
#  |-- name: string (nullable = true)

# %%
df.show()
# Out:
# +---+-------+
# |age|   name|
# +---+-------+
# | 30|  Alice|
# | 25|    Bob|
# | 35|Charlie|
# +---+-------+

# %%
df.describe()
# Out:
# DataFrame[summary: string, age: string, name: string]

# %%
df.summary().show()
# Out:
# +-------+----+-------+
# |summary| age|   name|
# +-------+----+-------+
# |  count|   3|      3|
# |   mean|30.0|   NULL|
# | stddev| 5.0|   NULL|
# |    min|  25|  Alice|
# |    25%|  25|   NULL|
# |    50%|  30|   NULL|
# |    75%|  35|   NULL|
# |    max|  35|Charlie|
# +-------+----+-------+

# %%
from pyspark.sql.types import StructField, StringType, IntegerType, StructType

# %%
data_schema= [StructField('age', IntegerType(), True),
              StructField('name', StringType(), True)]

# %%
final_struc= StructType(fields=data_schema)

# %%
df=spark.read.json('D:\Desktop\Python_DataScience\Spark\Spark_tutorials\people.json', schema=final_struc)
df.printSchema()
# Out:
# root
#  |-- age: integer (nullable = true)
#  |-- name: string (nullable = true)

# %%
df.show()
# Out:
# +---+-------+
# |age|   name|
# +---+-------+
# | 30|  Alice|
# | 25|    Bob|
# | 35|Charlie|
# +---+-------+

# %%
type(df['age'])
# Out:
# pyspark.sql.column.Column

# %%
df.select('age').show()
# Out:
# +---+
# |age|
# +---+
# | 30|
# | 25|
# | 35|
# +---+

# %%
df.head(2)
# Out:
# [Row(age=30, name='Alice'), Row(age=25, name='Bob')]

# %%
df.withColumn('age_after_10_years', df['age']+10).show()
# Out:
# +---+-------+------------------+
# |age|   name|age_after_10_years|
# +---+-------+------------------+
# | 30|  Alice|                40|
# | 25|    Bob|                35|
# | 35|Charlie|                45|
# +---+-------+------------------+

# %%
df.withColumnRenamed('age', 'my_new_age').show()
# Out:
# +----------+-------+
# |my_new_age|   name|
# +----------+-------+
# |        30|  Alice|
# |        25|    Bob|
# |        35|Charlie|
# +----------+-------+

# %%
df.createOrReplaceTempView('people')

# %%
results=spark.sql('SELECT * FROM people WHERE age=30')
results.show()
# Out:
# +---+-----+
# |age| name|
# +---+-----+
# | 30|Alice|
# +---+-----+
